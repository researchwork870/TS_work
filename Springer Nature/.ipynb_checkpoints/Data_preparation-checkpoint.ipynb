# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# In order to use this notebook for univarate time series analysis :-
# 1) The primary requirement is not to have missing values or categorial(string) data for time_dependent variable 
#    and time_column.
# 2) This cell requires information on file_name (only csv), time_dependent_variable, time_column, date_time format (frmt)
#    and resample grain(X). After filling the required information correctly, you can run all the cells (Cell ---> Run All)
# 3) Example :-
#   file_name               = "JetRail Avg Hourly Traffic Data - 2012-2013.csv"
#   time_dependent_variable = "Count"    (column name in your dataset)
#   time_column             = "Datetime" (column name in your dataset)
#   frmt                    = "%Y-%m-%d"
#   X                       = "D" 

file_name = "SPRBI-5213 - Order Data 002 2nd Half 2021 AT Processed.csv"
time_dependent_variable = "Total Sales Units consolidated"
time_column = "Order Date"

# %%
def data(time_column, file_name):
    if ".csv" in file_name:
        df = pd.read_csv(file_name, parse_dates=True)
    elif ".xlsx" in file_name:
        df = pd.read_excel(file_name, parse_dates=True)
    return df


df = data(time_column, file_name)

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name', 'dtypes']]
    summary['Missing'] = df.isnull().sum().values
    summary['Missing(% of Total values)'] = (
        100 * summary['Missing']) / df.shape[0]
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    return summary
    
resumetable(df)
# Out:
# Dataset Shape: (39033, 24)
#                                         Name   dtypes  Missing  \
# 0           Sales Document Item (compounded)   object      438
# 1                                 Order Date   object      439
# 2                           Invoice Document    int64        0
# 3                               Invoice Type   object        0
# 4                               Invoice Date   object        0
# 5                          Document currency   object        0
# 6                                   Material    int64        0
# 7                                Author Name   object        0
# 8                                 Product ID    int64        0
# 9                                    ISBN 13   object        0
# 10                          Title (complete)   object        0
# 11                                 Price EUR  float64        0
# 12                                 Price USD  float64        0
# ...

# %%
def msv(data, thresh = 20, color = 'black', edgecolor = 'black', height = 3, width = 15):
    
    plt.figure(figsize = (width, height))
    percentage = (data.isnull().mean()) * 100
    percentage.sort_values(ascending = False).plot.bar(color = color, edgecolor = edgecolor)
    
    plt.axhline(y = thresh, color = 'r', linestyle = '-')
    plt.title('Missing values percentage per column', fontsize=20, weight='bold' )
    
    #plt.text(len(data.isnull().sum()/len(data))/1.7, thresh+12.5, f'Columns with more than {thresh}% missing values', fontsize=12, color='crimson',
     #    ha='left' ,va='top')
   # plt.text(len(data.isnull().sum()/len(data))/1.7, thresh - 5, f'Columns with less than {thresh}% missing values', fontsize=12, color='green',
     #     ha='left' ,va='top')
    plt.xlabel('Columns', size=15, weight='bold')
    plt.ylabel('Missing values percentage')
    plt.yticks(weight ='bold')
    
    return plt.show()

msv(df,80)

# %%
import seaborn as sns

# Plot the Time series data
def graph(ts,product_id,frequency,time_column, time_dependent_variable):
    ts["Order Date"] = pd.to_datetime(ts["Order Date"])
    ts['Pub. date actual 1st release'] = pd.to_datetime(ts['Pub. date actual 1st release'])
    pub_date = ts[ts['Product ID'] == product_id]["Pub. date actual 1st release"].unique()
    ts.index = ts["Order Date"]
    ts_data = ts[ts['Product ID'] == product_id].resample(frequency)
    new = pd.DataFrame(ts_data["Total Sales Units consolidated"].sum()).reset_index()
    fig, ax = plt.subplots(figsize=(20, 7))
    a = sns.lineplot(x=time_column, y=time_dependent_variable, data=new)
    a.set_title("Product_id:{}".format(product_id), fontsize=15)
    plt.axvline(x = pub_date, color = 'r', linestyle = '-')
    plt.show()

# %%
prod_ids = [101809569,100847925,100095835,101853583,42076843]

for i in prod_ids:
    graph(df,i,"7D",time_column, time_dependent_variable)
